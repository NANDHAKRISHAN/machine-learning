# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target']=iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
df[df.target==1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
df['flower']=df.target.apply(lambda x: iris.target_names [x])

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target     flower
# 0         0     setosa
# 1         0     setosa
# 2         0     setosa
# 3         0     setosa
# 4         0     setosa
# ..      ...        ...
# 145       2  virginica
# 146       2  virginica
# 147       2  virginica
# 148       2  virginica
# 149       2  virginica
#
# [150 rows x 6 columns]

# %%
df[0:50]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# 11                4.8               3.4                1.6               0.2
# 12                4.8               3.0                1.4               0.1
# 13                4.3               3.0                1.1               0.1
# 14                5.8               4.0                1.2               0.2
# 15                5.7               4.4                1.5               0.4
# 16                5.4               3.9                1.3               0.4
# 17                5.1               3.5                1.4               0.3
# 18                5.7               3.8                1.7               0.3
# 19                5.1               3.8                1.5               0.3
# 20                5.4               3.4                1.7               0.2
# 21                5.1               3.7                1.5               0.4
# 22                4.6               3.6                1.0               0.2
# 23                5.1               3.3                1.7               0.5
# 24                4.8               3.4                1.9               0.2
# 25                5.0               3.0                1.6               0.2
# 26                5.0               3.4                1.6               0.4
# 27                5.2               3.5                1.5               0.2
# 28                5.2               3.4                1.4               0.2
# 29                4.7               3.2                1.6               0.2
# 30                4.8               3.1                1.6               0.2
# 31                5.4               3.4                1.5               0.4
# 32                5.2               4.1                1.5               0.1
# 33                5.5               4.2                1.4               0.2
# 34                4.9               3.1                1.5               0.2
# 35                5.0               3.2                1.2               0.2
# 36                5.5               3.5                1.3               0.2
# 37                4.9               3.6                1.4               0.1
# 38                4.4               3.0                1.3               0.2
# 39                5.1               3.4                1.5               0.2
# 40                5.0               3.5                1.3               0.3
# 41                4.5               2.3                1.3               0.3
# 42                4.4               3.2                1.3               0.2
# 43                5.0               3.5                1.6               0.6
# 44                5.1               3.8                1.9               0.4
# 45                4.8               3.0                1.4               0.3
# 46                5.1               3.8                1.6               0.2
# 47                4.6               3.2                1.4               0.2
# 48                5.3               3.7                1.5               0.2
# 49                5.0               3.3                1.4               0.2
#
#     target  flower
# 0        0  setosa
# 1        0  setosa
# 2        0  setosa
# 3        0  setosa
# 4        0  setosa
# 5        0  setosa
# 6        0  setosa
# 7        0  setosa
# 8        0  setosa
# 9        0  setosa
# 10       0  setosa
# 11       0  setosa
# 12       0  setosa
# 13       0  setosa
# 14       0  setosa
# 15       0  setosa
# 16       0  setosa
# 17       0  setosa
# 18       0  setosa
# 19       0  setosa
# 20       0  setosa
# 21       0  setosa
# 22       0  setosa
# 23       0  setosa
# 24       0  setosa
# 25       0  setosa
# 26       0  setosa
# 27       0  setosa
# 28       0  setosa
# 29       0  setosa
# 30       0  setosa
# 31       0  setosa
# 32       0  setosa
# 33       0  setosa
# 34       0  setosa
# 35       0  setosa
# 36       0  setosa
# 37       0  setosa
# 38       0  setosa
# 39       0  setosa
# 40       0  setosa
# 41       0  setosa
# 42       0  setosa
# 43       0  setosa
# 44       0  setosa
# 45       0  setosa
# 46       0  setosa
# 47       0  setosa
# 48       0  setosa
# 49       0  setosa

# %%
df[50:101]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# 55                 5.7               2.8                4.5               1.3
# 56                 6.3               3.3                4.7               1.6
# 57                 4.9               2.4                3.3               1.0
# 58                 6.6               2.9                4.6               1.3
# 59                 5.2               2.7                3.9               1.4
# 60                 5.0               2.0                3.5               1.0
# 61                 5.9               3.0                4.2               1.5
# 62                 6.0               2.2                4.0               1.0
# 63                 6.1               2.9                4.7               1.4
# 64                 5.6               2.9                3.6               1.3
# 65                 6.7               3.1                4.4               1.4
# 66                 5.6               3.0                4.5               1.5
# 67                 5.8               2.7                4.1               1.0
# 68                 6.2               2.2                4.5               1.5
# 69                 5.6               2.5                3.9               1.1
# 70                 5.9               3.2                4.8               1.8
# 71                 6.1               2.8                4.0               1.3
# 72                 6.3               2.5                4.9               1.5
# 73                 6.1               2.8                4.7               1.2
# 74                 6.4               2.9                4.3               1.3
# 75                 6.6               3.0                4.4               1.4
# 76                 6.8               2.8                4.8               1.4
# 77                 6.7               3.0                5.0               1.7
# 78                 6.0               2.9                4.5               1.5
# 79                 5.7               2.6                3.5               1.0
# 80                 5.5               2.4                3.8               1.1
# 81                 5.5               2.4                3.7               1.0
# 82                 5.8               2.7                3.9               1.2
# 83                 6.0               2.7                5.1               1.6
# 84                 5.4               3.0                4.5               1.5
# 85                 6.0               3.4                4.5               1.6
# 86                 6.7               3.1                4.7               1.5
# 87                 6.3               2.3                4.4               1.3
# 88                 5.6               3.0                4.1               1.3
# 89                 5.5               2.5                4.0               1.3
# 90                 5.5               2.6                4.4               1.2
# 91                 6.1               3.0                4.6               1.4
# 92                 5.8               2.6                4.0               1.2
# 93                 5.0               2.3                3.3               1.0
# 94                 5.6               2.7                4.2               1.3
# 95                 5.7               3.0                4.2               1.2
# 96                 5.7               2.9                4.2               1.3
# 97                 6.2               2.9                4.3               1.3
# 98                 5.1               2.5                3.0               1.1
# 99                 5.7               2.8                4.1               1.3
# 100                6.3               3.3                6.0               2.5
#
#      target      flower
# 50        1  versicolor
# 51        1  versicolor
# 52        1  versicolor
# 53        1  versicolor
# 54        1  versicolor
# 55        1  versicolor
# 56        1  versicolor
# 57        1  versicolor
# 58        1  versicolor
# 59        1  versicolor
# 60        1  versicolor
# 61        1  versicolor
# 62        1  versicolor
# 63        1  versicolor
# 64        1  versicolor
# 65        1  versicolor
# 66        1  versicolor
# 67        1  versicolor
# 68        1  versicolor
# 69        1  versicolor
# 70        1  versicolor
# 71        1  versicolor
# 72        1  versicolor
# 73        1  versicolor
# 74        1  versicolor
# 75        1  versicolor
# 76        1  versicolor
# 77        1  versicolor
# 78        1  versicolor
# 79        1  versicolor
# 80        1  versicolor
# 81        1  versicolor
# 82        1  versicolor
# 83        1  versicolor
# 84        1  versicolor
# 85        1  versicolor
# 86        1  versicolor
# 87        1  versicolor
# 88        1  versicolor
# 89        1  versicolor
# 90        1  versicolor
# 91        1  versicolor
# 92        1  versicolor
# 93        1  versicolor
# 94        1  versicolor
# 95        1  versicolor
# 96        1  versicolor
# 97        1  versicolor
# 98        1  versicolor
# 99        1  versicolor
# 100       2   virginica

# %%
#ploting

# %%
df0=df[0:50]
df1= df[50:100]
df2= df[100:]
  
    
import matplotlib.pyplot as plt

plt.xlabel("sepal length")
plt.ylabel("sepal width")
plt.scatter(df0["sepal length (cm)"],df0["sepal width (cm)"],color='green',marker='+')
plt.scatter(df1["sepal length (cm)"],df1["sepal width (cm)"],color='red',marker='*')

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['target','flower'], axis='columns')
y = df.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
model.predict([[4,9,35,1]])
# Out:
# C:\Users\nandh\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([0])
